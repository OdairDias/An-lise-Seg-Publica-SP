# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Locale: Utilizado para formatação de datas, valores, dias de acordo com a região que queremos.
import locale

# %% [markdown]
# # Fonte dos dados: http://www.ssp.sp.gov.br/transparenciassp/Consulta.aspx

# %%
#comando utilizado para exibir todas as colunas
pd.set_option('display.max_columns',None)

# %%
roubos_celulares=pd.read_csv('dados_roubo_celulares.csv',encoding='ISO-8859-1', sep = ';')

# %%
#retirando todas as colunas vazias
limpeza_colunas= roubos_celulares.dropna(axis=1, how='all')

# %%
#retirando todas as linhas completamente vazias
limpeza_colunas=roubos_celulares.dropna(how='all')

# %%
roubos_celulares=limpeza_colunas

# %%
roubos_celulares.head(5)
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM       BO_INICIADO        BO_EMITIDO  \
# 0    2022  1710085   1710085/2022  01/10/2022 00:08  01/10/2022 00:08
# 1    2022     2381      2381/2022  01/10/2022 00:17  01/10/2022 00:17
# 2    2022     7423      7423/2022  01/10/2022 00:20  01/10/2022 00:20
# 3    2022     7423      7423/2022  01/10/2022 00:20  01/10/2022 00:20
# 4    2022   134311    134311/2022  01/10/2022 00:27  01/10/2022 00:27
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     30/09/2022          18:00          A NOITE      30/09/2022
# 1     30/09/2022          23:30          A NOITE      30/09/2022
# 2     30/09/2022          20:00          A NOITE      30/09/2022
# 3     30/09/2022          20:00          A NOITE      30/09/2022
# 4     30/09/2022          18:30          A NOITE      30/09/2022
#
#      DATAELABORACAO    BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 0  01/10/2022 00:08  Desconhecida       Não                      NaN
# ...

# %%
roubos_celulares.tail(5)
# Out:
#        ANO_BO  NUM_BO NUMERO_BOLETIM       BO_INICIADO        BO_EMITIDO  \
# 24300    2022  164134    164134/2022  31/10/2022 23:41  31/10/2022 23:41
# 24301    2022  164289    164289/2022  31/10/2022 23:50  31/10/2022 23:50
# 24302    2022    8247      8247/2022  31/10/2022 23:55  31/10/2022 23:55
# 24303    2022    3375      3375/2022  31/10/2022 23:58  31/10/2022 23:58
# 24304    2022    1424      1424/2022  31/10/2022 23:58  31/10/2022 23:58
#
#       DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 24300     19/10/2022          15:00          A TARDE      31/10/2022
# 24301     29/10/2022          02:30     DE MADRUGADA      31/10/2022
# 24302     31/10/2022          21:10          A NOITE      31/10/2022
# 24303     31/10/2022          22:50          A NOITE      31/10/2022
# 24304     30/10/2022          02:00     DE MADRUGADA      31/10/2022
#
#          DATAELABORACAO    BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# ...

# %%
roubos_celulares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24305 entries, 0 to 24304
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ANO_BO                    24305 non-null  int64
#  1   NUM_BO                    24305 non-null  int64
#  2   NUMERO_BOLETIM            24305 non-null  object
#  3   BO_INICIADO               24305 non-null  object
#  4   BO_EMITIDO                24305 non-null  object
#  5   DATAOCORRENCIA            24305 non-null  object
#  6   HORAOCORRENCIA            22528 non-null  object
#  7   PERIDOOCORRENCIA          24305 non-null  object
#  8   DATACOMUNICACAO           24305 non-null  object
#  9   DATAELABORACAO            24305 non-null  object
#  10  BO_AUTORIA                24305 non-null  object
#  11  FLAGRANTE                 24305 non-null  object
#  12  NUMERO_BOLETIM_PRINCIPAL  6639 non-null   object
# ...

# %%
# aqui estamos verificando onde temos valores nulos.
roubos_celulares.isnull().sum()
# Out:
# ANO_BO                          0
# NUM_BO                          0
# NUMERO_BOLETIM                  0
# BO_INICIADO                     0
# BO_EMITIDO                      0
# DATAOCORRENCIA                  0
# HORAOCORRENCIA               1777
# PERIDOOCORRENCIA                0
# DATACOMUNICACAO                 0
# DATAELABORACAO                  0
# BO_AUTORIA                      0
# FLAGRANTE                       0
# NUMERO_BOLETIM_PRINCIPAL    17666
# LOGRADOURO                   1073
# NUMERO                         39
# BAIRRO                        325
# CIDADE                         39
# UF                             39
# LATITUDE                     2981
# LONGITUDE                    2981
# DESCRICAOLOCAL                  0
# EXAME                       24305
# SOLUCAO                         0
# DELEGACIA_NOME                  0
# DELEGACIA_CIRCUNSCRICAO         0
# ESPECIE                         0
# RUBRICA                         0
# ...

# %%
# Aqui estamos descrevendo quais modelos de celulares são os mais furtados por marca.
roubos_celulares.groupby(['MARCA_CELULAR']).size()
# Out:
# MARCA_CELULAR
# APPLE            1
# Alcatel          9
# Apple         5692
# Asus           212
# BLU             20
# Huawei          32
# LG             719
# Lenovo          18
# Microsoft        5
# Motorola      5927
# Multilaser      48
# Nokia           50
# Outros         728
# Positivo       145
# Samsung       8653
# Siemens         14
# Sony             4
# Xiaomi        1982
# ZTE              1
# dtype: int64

# %%
# Aqui apresentamos a quantidade de aparelhos roubados e a frequência com que ocorreu
roubos_celulares.groupby(['QUANT_CELULAR']).size()
# Out:
# QUANT_CELULAR
# 1.0      23835
# 2.0        270
# 3.0         60
# 4.0         31
# 5.0         10
# 6.0          4
# 8.0          2
# 9.0         12
# 10.0         2
# 11.0         1
# 12.0         1
# 13.0         1
# 14.0         2
# 15.0         2
# 17.0        12
# 20.0         4
# 23.0         1
# 39.0         1
# 48.0         1
# 51.0         2
# 101.0        2
# 135.0        1
# 198.0        1
# 300.0        2
# dtype: int64

# %%
roubos_celulares.groupby(['CIDADE']).size()
# Out:
# CIDADE
# ADAMANTINA          1
# AGUAI               1
# AGUDOS              1
# ALUMINIO            2
# AMERICANA          39
#                    ..
# VARZEA PAULISTA    25
# VERA CRUZ           4
# VINHEDO            41
# VIRADOURO           2
# VOTORANTIM         13
# Length: 244, dtype: int64

# %%
roubos_celulares.groupby(['BAIRRO']).size()
# Out:
# BAIRRO
# (L-9)                       1
# .                           1
# A Definir                   1
# ABERNESSIA                  1
# ADALGISA                    1
#                            ..
# Água Branca                30
# Água Chata                  3
# Água Espraiada              1
# Água Funda                  2
# Área Rural de Rio Claro     2
# Length: 3412, dtype: int64

# %%
# Agora vamos tratar a variavel DATA_
