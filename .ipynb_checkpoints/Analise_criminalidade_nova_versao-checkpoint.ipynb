# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Locale: Utilizado para formatação de datas, valores, dias de acordo com a região que queremos.
import locale 
#Warnings: Possui detalhes sobre os avisos e alertas que aparecem, porém podemos utiliza-lo também para que os alertas de
#futuras atualizações e metodos depreciados não sejam exibidos
import warnings
warnings.filterwarnings("ignore") 
from shapely.geometry import Point
import geopandas as gpd
import folium

# %% [markdown]
# # Fonte dos dados: http://www.ssp.sp.gov.br/transparenciassp/Consulta.aspx

# %%
#comando utilizado para exibir todas as colunas
pd.set_option('display.max_columns',None)

# %%
# Criando variavel principal
roubos_celulares=pd.read_excel('dados_roubo celulares_sp_outubro_2022.xlsx')

# %%
# Aqui estamos verificando as informações das primeiras colunas
roubos_celulares.head()
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM         BO_INICIADO          BO_EMITIDO  \
# 0    2022  1710085   1710085/2022 2022-10-01 00:08:00 2022-10-01 00:08:00
# 1    2022     2381      2381/2022 2022-10-01 00:17:00 2022-10-01 00:17:00
# 2    2022     7423      7423/2022 2022-10-01 00:20:00 2022-10-01 00:20:00
# 3    2022     7423      7423/2022 2022-10-01 00:20:00 2022-10-01 00:20:00
# 4    2022   134311    134311/2022 2022-10-01 00:27:00 2022-10-01 00:27:00
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO      DATAELABORACAO  \
# 0     2022-09-30          A NOITE      2022-09-30 2022-10-01 00:08:00
# 1     2022-09-30          A NOITE      2022-09-30 2022-10-01 00:17:00
# 2     2022-09-30          A NOITE      2022-09-30 2022-10-01 00:20:00
# 3     2022-09-30          A NOITE      2022-09-30 2022-10-01 00:20:00
# 4     2022-09-30          A NOITE      2022-09-30 2022-10-01 00:27:00
#
#      BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 0  Desconhecida       Não                      NaN
# 1  Desconhecida       Não                      NaN
# 2     Conhecida       Sim                      NaN
# 3     Conhecida       Sim                      NaN
# 4  Desconhecida       Não                      NaN
#
#                        LOGRADOURO  NUMERO          BAIRRO    CIDADE  UF  \
# 0                   RUA PARATINGA    81.0       CONCEICAO   DIADEMA  SP
# 1               RUA JOSE RAFAELLI   272.0         SOCORRO   S.PAULO  SP
# 2  Avenida Senador Lacerda Franco   970.0  Jardim do Lago  CAMPINAS  SP
# 3  Avenida Senador Lacerda Franco   970.0  Jardim do Lago  CAMPINAS  SP
# 4                RUA DENIS FURTEL    91.0        PEDREIRA   S.PAULO  SP
#
#     LATITUDE  LONGITUDE DESCRICAOLOCAL  EXAME                         SOLUCAO  \
# 0 -23.702040 -46.620427    Via pública    NaN            BO PARA INVESTIGAÇÃO
# 1 -23.666840 -46.722660    Via pública    NaN            BO PARA INVESTIGAÇÃO
# 2 -22.936142 -47.088884    Via pública    NaN               BO PARA FLAGRANTE
# 3 -22.936142 -47.088884    Via pública    NaN               BO PARA FLAGRANTE
# 4 -23.704287 -46.628890    Via pública    NaN  ENCAMINHAMENTO DP ÁREA DO FATO
#
#              DELEGACIA_NOME DELEGACIA_CIRCUNSCRICAO  \
# 0      DELEGACIA ELETRONICA        01º D.P. DIADEMA
# 1         102º D.P. SOCORRO       102º D.P. SOCORRO
# 2  PLANTÃO - 01 DP CAMPINAS       02º D.P. CAMPINAS
# 3  PLANTÃO - 01 DP CAMPINAS       02º D.P. CAMPINAS
# 4    DELEGACIA ELETRONICA 1  98º D.P. JARDIM MIRIAM
#
#                                     ESPECIE                     RUBRICA  \
# 0  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 1  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 2  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 3  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 4  Título II - Patrimônio (arts. 155 a 183)   Roubo (art. 157) - OUTROS
#
#   DESDOBRAMENTO     STATUS TIPOPESSOA VITIMAFATAL NATURALIDADE NACIONALIDADE  \
# 0           NaN  Consumado        NaN         NaN          NaN           NaN
# 1           NaN  Consumado        NaN         NaN          NaN           NaN
# 2           NaN  Consumado        NaN         NaN          NaN           NaN
# 3           NaN  Consumado        NaN         NaN          NaN           NaN
# 4           NaN  Consumado        NaN         NaN          NaN           NaN
#
#   SEXO DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO GRAUINSTRUCAO  CORCUTIS  \
# 0  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 1  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 2  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 3  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 4  NaN            NaT    NaN         NaN       NaN           NaN       NaN
#
#   NATUREZAVINCULADA TIPOVINCULO  RELACIONAMENTO  PARENTESCO PLACA_VEICULO  \
# 0               NaN         NaN             NaN         NaN       DXF9J96
# 1               NaN         NaN             NaN         NaN       FNW7B16
# 2               NaN         NaN             NaN         NaN       GBT1A77
# 3               NaN         NaN             NaN         NaN       GBT1A77
# 4               NaN         NaN             NaN         NaN           NaN
#
#   UF_VEICULO CIDADE_VEICULO DESCR_COR_VEICULO       DESCR_MARCA_VEICULO  \
# 0         SP        DIADEMA          Vermelho          I/TOYOTA COROLLA
# 1         SP        S.PAULO            Branco             HONDA/ADV 150
# 2         SP       CAMPINAS             Preta  I/TOYOTA HILUX CDSRXA4FD
# 3         SP       CAMPINAS             Preta  I/TOYOTA HILUX CDSRXA4FD
# 4        NaN            NaN               NaN                       NaN
#
#    ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  QUANT_CELULAR MARCA_CELULAR
# 0          2022.0         NaN          AUTOMOVEL            1.0       Samsung
# 1          2021.0      2022.0           MOTONETA            1.0         Apple
# 2          2022.0      2022.0        CAMINHONETE            1.0         Apple
# 3          2022.0      2022.0        CAMINHONETE            1.0       Samsung
# 4             0.0         0.0                NaN            1.0        Xiaomi

# %%
# verificar como estão organizados os dados de latidute e  longitude no nosso mapa
roubos_celulares[['LATITUDE','LONGITUDE']]
# Out:
#         LATITUDE  LONGITUDE
# 0     -23.702040 -46.620427
# 1     -23.666840 -46.722660
# 2     -22.936142 -47.088884
# 3     -22.936142 -47.088884
# 4     -23.704287 -46.628890
# ...          ...        ...
# 24300 -23.552322 -46.646097
# 24301 -23.548481 -46.642623
# 24302 -23.626642 -46.648828
# 24303 -23.651202 -46.575947
# 24304 -23.558067 -46.403499
#
# [24305 rows x 2 columns]

# %%
#aqui estamos vendo as informaões dos dados de Latitude e longitude e se temos valores nulos 
roubos_celulares[['LATITUDE','LONGITUDE']].info()
roubos_celulares[['LATITUDE','LONGITUDE']].isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24305 entries, 0 to 24304
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATITUDE   21324 non-null  float64
#  1   LONGITUDE  21324 non-null  float64
# dtypes: float64(2)
# memory usage: 379.9 KB
# LATITUDE     2981
# LONGITUDE    2981
# dtype: int64

# %%
#Aqui estamos tirando do nosos conjunto de dados as linhas com valores nulos
# em seguida estamos vizualizando se o procedimento foi realizado de fato
roubos_celulares=roubos_celulares.dropna(subset= ['LATITUDE','LONGITUDE'])
roubos_celulares[['LATITUDE','LONGITUDE']].info()
roubos_celulares[['LATITUDE','LONGITUDE']].isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21324 entries, 0 to 24304
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATITUDE   21324 non-null  float64
#  1   LONGITUDE  21324 non-null  float64
# dtypes: float64(2)
# memory usage: 499.8 KB
# LATITUDE     0
# LONGITUDE    0
# dtype: int64

# %%
# com os dados limpos, vamos criar uma georeferencia para nosso conjunto de dados:
roubos_celulares['geometry'] = None

for index, row in roubos_celulares.iterrows():
    roubos_celulares.loc[index,'geometry'] = Point(row.LONGITUDE,row.LATITUDE)

# %%
# vamos verificar se foi criada uma nova coluna geometry no nosso DataSet
roubos_celulares.head()
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM         BO_INICIADO          BO_EMITIDO  \
# 0    2022  1710085   1710085/2022 2022-10-01 00:08:00 2022-10-01 00:08:00
# 1    2022     2381      2381/2022 2022-10-01 00:17:00 2022-10-01 00:17:00
# 2    2022     7423      7423/2022 2022-10-01 00:20:00 2022-10-01 00:20:00
# 3    2022     7423      7423/2022 2022-10-01 00:20:00 2022-10-01 00:20:00
# 4    2022   134311    134311/2022 2022-10-01 00:27:00 2022-10-01 00:27:00
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     2022-09-30       18:00:00          A NOITE      2022-09-30
# 1     2022-09-30       23:30:00          A NOITE      2022-09-30
# 2     2022-09-30       20:00:00          A NOITE      2022-09-30
# 3     2022-09-30       20:00:00          A NOITE      2022-09-30
# 4     2022-09-30       18:30:00          A NOITE      2022-09-30
#
#        DATAELABORACAO    BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 0 2022-10-01 00:08:00  Desconhecida       Não                      NaN
# 1 2022-10-01 00:17:00  Desconhecida       Não                      NaN
# 2 2022-10-01 00:20:00     Conhecida       Sim                      NaN
# 3 2022-10-01 00:20:00     Conhecida       Sim                      NaN
# 4 2022-10-01 00:27:00  Desconhecida       Não                      NaN
#
#                        LOGRADOURO  NUMERO          BAIRRO    CIDADE  UF  \
# 0                   RUA PARATINGA    81.0       CONCEICAO   DIADEMA  SP
# 1               RUA JOSE RAFAELLI   272.0         SOCORRO   S.PAULO  SP
# 2  Avenida Senador Lacerda Franco   970.0  Jardim do Lago  CAMPINAS  SP
# 3  Avenida Senador Lacerda Franco   970.0  Jardim do Lago  CAMPINAS  SP
# 4                RUA DENIS FURTEL    91.0        PEDREIRA   S.PAULO  SP
#
#     LATITUDE  LONGITUDE DESCRICAOLOCAL  EXAME                         SOLUCAO  \
# 0 -23.702040 -46.620427    Via pública    NaN            BO PARA INVESTIGAÇÃO
# 1 -23.666840 -46.722660    Via pública    NaN            BO PARA INVESTIGAÇÃO
# 2 -22.936142 -47.088884    Via pública    NaN               BO PARA FLAGRANTE
# 3 -22.936142 -47.088884    Via pública    NaN               BO PARA FLAGRANTE
# 4 -23.704287 -46.628890    Via pública    NaN  ENCAMINHAMENTO DP ÁREA DO FATO
#
#              DELEGACIA_NOME DELEGACIA_CIRCUNSCRICAO  \
# 0      DELEGACIA ELETRONICA        01º D.P. DIADEMA
# 1         102º D.P. SOCORRO       102º D.P. SOCORRO
# 2  PLANTÃO - 01 DP CAMPINAS       02º D.P. CAMPINAS
# 3  PLANTÃO - 01 DP CAMPINAS       02º D.P. CAMPINAS
# 4    DELEGACIA ELETRONICA 1  98º D.P. JARDIM MIRIAM
#
#                                     ESPECIE                     RUBRICA  \
# 0  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 1  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 2  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 3  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 4  Título II - Patrimônio (arts. 155 a 183)   Roubo (art. 157) - OUTROS
#
#   DESDOBRAMENTO     STATUS TIPOPESSOA VITIMAFATAL NATURALIDADE NACIONALIDADE  \
# 0           NaN  Consumado        NaN         NaN          NaN           NaN
# 1           NaN  Consumado        NaN         NaN          NaN           NaN
# 2           NaN  Consumado        NaN         NaN          NaN           NaN
# 3           NaN  Consumado        NaN         NaN          NaN           NaN
# 4           NaN  Consumado        NaN         NaN          NaN           NaN
#
#   SEXO DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO GRAUINSTRUCAO  CORCUTIS  \
# 0  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 1  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 2  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 3  NaN            NaT    NaN         NaN       NaN           NaN       NaN
# 4  NaN            NaT    NaN         NaN       NaN           NaN       NaN
#
#   NATUREZAVINCULADA TIPOVINCULO  RELACIONAMENTO  PARENTESCO PLACA_VEICULO  \
# 0               NaN         NaN             NaN         NaN       DXF9J96
# 1               NaN         NaN             NaN         NaN       FNW7B16
# 2               NaN         NaN             NaN         NaN       GBT1A77
# 3               NaN         NaN             NaN         NaN       GBT1A77
# 4               NaN         NaN             NaN         NaN           NaN
#
#   UF_VEICULO CIDADE_VEICULO DESCR_COR_VEICULO       DESCR_MARCA_VEICULO  \
# 0         SP        DIADEMA          Vermelho          I/TOYOTA COROLLA
# 1         SP        S.PAULO            Branco             HONDA/ADV 150
# 2         SP       CAMPINAS             Preta  I/TOYOTA HILUX CDSRXA4FD
# 3         SP       CAMPINAS             Preta  I/TOYOTA HILUX CDSRXA4FD
# 4        NaN            NaN               NaN                       NaN
#
#    ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  QUANT_CELULAR MARCA_CELULAR  \
# 0          2022.0         NaN          AUTOMOVEL            1.0       Samsung
# 1          2021.0      2022.0           MOTONETA            1.0         Apple
# 2          2022.0      2022.0        CAMINHONETE            1.0         Apple
# 3          2022.0      2022.0        CAMINHONETE            1.0       Samsung
# 4             0.0         0.0                NaN            1.0        Xiaomi
#
#                            geometry
# 0  POINT (-46.6204273 -23.70204035)
# 1  POINT (-46.7226596 -23.66683992)
# 2    POINT (-47.0888835 -22.936142)
# 3    POINT (-47.0888835 -22.936142)
# 4    POINT (-46.62889 -23.70428665)

# %%
# Agora vamos mostrar os dados gerados a cima
gdf_rcelulares=gpd.GeoDataFrame(roubos_celulares,geometry='geometry')
gdf_rcelulares.plot()
# Out:
# <AxesSubplot:>

# %%
type(gdf_rcelulares)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# vamos filtar pelas regiões onde mais ocorream crimes
roubos_celulares['CIDADE'].value_counts()
# Out:
# S.PAULO                11879
# S.BERNARDO DO CAMPO      763
# GUARULHOS                718
# S.ANDRE                  646
# OSASCO                   485
#                        ...
# ANALANDIA                  1
# CACHOEIRA PAULISTA         1
# ITAPEVA                    1
# AGUDOS                     1
# S.SIMAO                    1
# Name: CIDADE, Length: 236, dtype: int64

# %%
gdf_municipios= gpd.read_file('geolocalição_grande_sp.json', driver= 'GeoJSON')
gdf_municipios.plot()
# Out:
# <AxesSubplot:>

# %%
#transformando variavel no tipo polygon
polygon_Mapa=gdf_municipios.iloc[0].geometry

# %%
polygon_Mapa
# Out:
# <POLYGON ((-45.962 -23.497, -45.962 -23.498, -45.961 -23.499, -45.961 -23.49...>

# %%
type(polygon_Mapa)
# Out:
# shapely.geometry.polygon.Polygon

# %%
#cruzando os dados com o polygon da região da grande SP
gfd_dados_cruzados=gdf_rcelulares[gdf_rcelulares.intersects(polygon_Mapa)]

# %%
#mostrando os dados cruzados a cima 
fig, ax= plt.subplots(figsize=(5,5))
gfd_dados_cruzados.plot(ax=ax)
gdf_municipios.plot(ax=ax, facecolor='none',edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
gfd_dados_cruzados.crs = "epsg:4326"
gfd_dados_cruzados =gfd_dados_cruzados.to_crs(epsg=3857)

# %%
#gfd_dados_cruzados.to_file('dados_cruzados_df_geo.Json',driver='GeoJSON')

# %%
fmap=folium.Map()
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6af879a0a6c7023fce3884639148c37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6af879a0a6c7023fce3884639148c37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6af879a0a6c7023fce3884639148c37 = L.map(
#                 &quot;map_f6af879a0a6c7023fce3884639148c37&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32983b77c711ae7446cc7e95ea25afbc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f6af879a0a6c7023fce3884639148c37);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#fmap=folium.Map()
#feat_geojson= folium.features.GeoJson(gfd_dados_cruzados)
#fmap.add_child(feat_geojson)
#fmap

# %%
# Aqui estamos descrevendo quais modelos de celulares são os mais furtados por marca.
celulares_por_marca=roubos_celulares.groupby(['MARCA_CELULAR']).size()
celulares_por_marca
# Out:
# MARCA_CELULAR
# APPLE            1
# Alcatel          9
# Apple         5692
# Asus           212
# BLU             20
# Huawei          32
# LG             719
# Lenovo          18
# Microsoft        5
# Motorola      5927
# Multilaser      48
# Nokia           50
# Outros         728
# Positivo       145
# Samsung       8653
# Siemens         14
# Sony             4
# Xiaomi        1982
# ZTE              1
# dtype: int64

# %%
# Aqui apresentamos a quantidade de aparelhos roubados e a frequência com que ocorreu
celulares=roubos_celulares.groupby(['QUANT_CELULAR']).size()
#roubos_celulares.QUANT_CELULAR.value_counts().plot(kind='bar', title=' Periodo Ocorrencia',color = ['#1F77B4', '#FF7F0E']);
celulares
# Out:
# QUANT_CELULAR
# 1.0      23835
# 2.0        270
# 3.0         60
# 4.0         31
# 5.0         10
# 6.0          4
# 8.0          2
# 9.0         12
# 10.0         2
# 11.0         1
# 12.0         1
# 13.0         1
# 14.0         2
# 15.0         2
# 17.0        12
# 20.0         4
# 23.0         1
# 39.0         1
# 48.0         1
# 51.0         2
# 101.0        2
# 135.0        1
# 198.0        1
# 300.0        2
# dtype: int64

# %%
# Aqui estamos filtrando pelas cinco primeiras cidades de maiores ocorrência
roubos_celulares['CIDADE'].value_counts()
# Out:
# S.PAULO                13300
# S.BERNARDO DO CAMPO      952
# GUARULHOS                800
# S.ANDRE                  704
# OSASCO                   618
#                        ...
# CACHOEIRA PAULISTA         1
# ITAPEVA                    1
# AGUDOS                     1
# SERRANA                    1
# S.SIMAO                    1
# Name: CIDADE, Length: 244, dtype: int64

# %%
# Aqui estamos filtrando por período de  ocorrência 
periodo_oc=roubos_celulares.groupby(['PERIDOOCORRENCIA']).size()
periodo_oc
#roubos_celulares.PERIDOOCORRENCIA.value_counts().plot(kind='bar', title=' Periodo Ocorrencia',color = ['#1F77B4', '#FF7F0E']);
# Out:
# PERIDOOCORRENCIA
# A NOITE            10249
# A TARDE             4703
# DE MADRUGADA        4460
# EM HORA INCERTA       95
# PELA MANHÃ          4798
# dtype: int64

# %%
# apresentando os dados por Bairro onde ocorreram os roubos
roubos_celulares['BAIRRO'].value_counts()
# Out:
# CENTRO                   484
# Centro                   335
# REPUBLICA                327
# JABAQUARA                228
# CAPAO REDONDO            221
#                         ...
# Chácara do Conde           1
# VILA MAYOR                 1
# ZONA CENTRAL               1
# Cidade Morumbi             1
# Vila dos Comerciarios      1
# Name: BAIRRO, Length: 3412, dtype: int64

# %%
# Apresentadno os dados das cinco ruas onde ocorreram maiores  furtos
roubos_celulares['LOGRADOURO'].value_counts()
# Out:
# RUA AMERICO VESPUCCI                 112
# ACESSO RODOVIA CASTELO BRANCO         93
# RUA COMENDADOR NESTOR PEREIRA         89
# RODOVIA PRESIDENTE DUTRA (BR 116)     75
# Avenida Ragueb Chohfi                 69
#                                     ...
# RUA DA FE                              1
# RUA DESEMBARGADOR DO VALE              1
# Rua Nilza Maria Pereira Simplicio      1
# RUA JOSÉ TEIXEIRA                      1
# RUA PEDRO DA SILVEIRA                  1
# Name: LOGRADOURO, Length: 9881, dtype: int64

# %%
# Agora vamos tratar a variavel DATA_
#trazendo dados para o formato português Brasil
# Transformamos dados apra filtra quais dias da semana possuem maior ocorrência de roubo 
locale.setlocale(locale.LC_ALL, 'pt_BR.utf8')

roubos_celulares['DATAOCORRENCIA'] =  pd.to_datetime(roubos_celulares['DATAOCORRENCIA'], format= '%d/%m/%Y')
roubos_celulares['DATAOCORRENCIA'] = roubos_celulares['DATAOCORRENCIA'].dt.date
roubos_celulares['ANO_OCORRENCIA'] = pd.DatetimeIndex(roubos_celulares['DATAOCORRENCIA']).year
roubos_celulares['MES_OCORRENCIA'] = pd.DatetimeIndex(roubos_celulares['DATAOCORRENCIA']).month
roubos_celulares['DIA_OCORRENCIA'] = pd.DatetimeIndex(roubos_celulares['DATAOCORRENCIA']).day
roubos_celulares['DIA_SEMANA_OCORRENCIA'] = pd.DatetimeIndex(roubos_celulares['DATAOCORRENCIA']).day_name(locale = 'pt_BR.utf8')

plt.rcParams["figure.figsize"] = [8.00, 8.00]
plt.rcParams["figure.autolayout"] = True
roubos_celulares.DIA_SEMANA_OCORRENCIA.value_counts().plot(kind='bar', title='Ocorrência de Roubo por dia da semana',color = ['#1F77B4', '#FF7F0E']);

# %%
from prettytable import PrettyTable
